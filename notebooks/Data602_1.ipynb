# %%
# !pip install numpy pandas matplotlib scikit-learn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets

print("Packages imported successfully!")
# Out:
# Packages imported successfully!

# %%
#Lab: 2.3.3, 2.3.6, & 2.3.7 - Solutions of exercises: 8 a-c
# Step 1: Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Step 2: Import necessary libraries
import pandas as pd

# Step 3: Provide the path to the 'College.csv' file
file_path = '/content/drive/MyDrive/Colab Notebooks/College.csv'

# Step 4: Load the dataset
college = pd.read_csv(file_path)

# Step 5: Check the first few rows of the dataset
print("Initial DataFrame:")
print(college.head())

# Step 6: (b) Rename and set index to the 'College' column
college2 = pd.read_csv(file_path, index_col=0)
college3 = college2.rename(columns={'Unnamed: 0': 'College'})
print("\nModified DataFrame with College as index:")
print(college3.head())

# Step 7: (c) Use describe() method to generate a summary of the dataset
print("\nSummary statistics of the dataset:")
print(college3.describe())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Initial DataFrame:
#                      Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# ...
